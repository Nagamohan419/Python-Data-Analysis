# %% [markdown]
# ## Matplotlib¶
#         Line chart
#         Pie chart
#         Scatter Plot
#         Bar chart
#         Box Plot
#         Histogram

# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
np.__version__
# Out:
# '1.19.5'

# %%
np.random.uniform(75.5, 125.5, size=(2, 2)).round(2)
# Out:
# array([[115.6 , 106.04],
#        [107.22,  80.67]])

# %% [markdown]
# ## Line Plot
#
# A plot is a graphical representation of data, which shows the relationship between two variables
# or the distribution of data

# %%
temparature = np.random.uniform(18,43, size=40)
plt.plot(temparature)
plt.show()

# %% [markdown]
# #### Use seed from np.random

# %%
np.random.seed(111)
np.random.randint(10,20, size=10)
# Out:
# array([14, 14, 14, 16, 13, 19, 12, 16, 12, 18])

# %%
np.random.seed(123)
temparature = np.random.randint(20,40, size=40)
plt.plot(temparature)
plt.show()

# %% [markdown]
# ### Modify the size of the chart

# %%
plt.figure(figsize=(13,3))
np.random.seed(123)
temparature = np.random.randint(20,40, size=40)
plt.plot(temparature)
plt.show()

# %%
plt.figure(figsize=(15,7))

winter = np.random.randint(16,28, size=30)
plt.plot(winter)

summer = np.random.randint(26,39, size=30)
plt.plot(summer)

rainfall = np.random.randint(6,130, size=30)
plt.plot(rainfall)


plt.show()

# %% [markdown]
# ### Add other properties to the chart

# %%
plt.figure(figsize=(15,7))

low = np.random.randint(15,26, size=12)
plt.plot(low)

high = np.random.randint(28,39, size=12)
plt.plot(high)

plt.title('Average High & Low temp in Hyderabad ')
plt.xlabel('Month')
plt.ylabel('Temp in °C')
plt.legend(['Low', 'High'], loc='best')

plt.show()

# %%
plt.figure(figsize=(15,7))

low = np.random.randint(15,26, size=12)
plt.plot(low, linestyle = '--', color = '#0cb577', lw = 4)

high = np.random.randint(28,39, size=12)
plt.plot(high, linestyle = ':', color = 'lime', lw = 3)

plt.title('Average High & Low temp in Hyderabad ')
plt.xlabel('Month')
plt.ylabel('Temp in °C')
plt.legend(['Low', 'High'], loc='best')

plt.xticks(np.arange(0,16,2.5))
plt.yticks(np.arange(10,36,5))

plt.show()

# %% [markdown]
# ## 2. Pie chart
#
# Pie charts are used to show percentage or proportional data.
# matplotlib provides the pie() method to create pie charts
#
# ### It has several advantages:
# • Summarizes a large dataset in visual form
# • Displays the relative proportions of multiple
# classes of data
# • Size of the circle is made proportional to the
# total quantity

# %%
values = [145, 411, 34, 141, 25, 256]

labels = ['China', 'India', 'USA', 'Indonesia', 'Brazil', 'Pakistan']
plt.pie(values,labels= labels)
plt.show();

# %%
# Data: Country wise Density(pop/km2)

plt.figure(figsize=(10,10))

values = [145, 411, 34, 141, 25, 256]
colors = ['peru','lightgreen','slategrey','lightpink','lightblue','coral']
labels = ['China', 'India', 'USA', 'Indonesia', 'Brazil', 'Pakistan']
explode = (0, 0.1, 0, 0, 0, 0)
plt.pie(values, colors=colors, labels= labels,explode=explode,shadow=True)
plt.title('Population Density per KM2')
plt.legend(labels,loc=0) # 0 for best
plt.show()

# %%
# Data: Country wise Density(pop/km2)

plt.figure(figsize=(10,10))

values = [145, 411, 34, 141, 25, 256]
colors = ['peru','lightgreen','slategrey','lightpink','lightblue','coral']
labels = ['China', 'India', 'USA', 'Indonesia', 'Brazil', 'Pakistan']
explode = (0, 0.1, 0, 0, 0, 0)
plt.pie(values, colors=colors, labels= labels,explode=explode,counterclock=False, 
        shadow=True, autopct='%0.2f%%')
plt.title('Population Density per KM2')
plt.legend(labels,loc=0) # 0 for best
plt.show()

# %% [markdown]
# ## 3. Scatter Plot
#
# A scatter plot is used to graphically display the relationships between variables.
# However, to control a plot, it is recommended to use scatter() method.
#
#
# ### It has several advantages:
#
# • Shows the correlation between variables
# • Is suitable for large datasets
# • Is easy to find clusters
# • Is possible to represent each piece of data as a
# point on the plot

# %%
np.random.seed(123)

# Generate a random float number using a numpy between any float range
wt = np.random.uniform(60.1,68.5, size = 10)
ht = np.random.uniform(124.3,168.7, size = 10)
 
plt.scatter(wt,ht,c='red',marker='D')
plt.xlabel('weight', fontsize=16)
plt.ylabel('height', fontsize=16)
plt.title('scatter plot - height vs weight',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(10,5))
np.random.seed(123)

# Generate a random float number using a numpy between any float range
wt_m = np.random.uniform(60.1,68.5, size = 10)
ht_m = np.random.uniform(124.3,168.7, size = 10)

wt_f = np.random.uniform(45.5,61.5, size = 10)
ht_f = np.random.uniform(110.3,155.5, size = 10)
 
plt.scatter(wt_m,ht_m,c='red',marker='s',label = 'Male' )
plt.scatter(wt_f,ht_f,c='green',marker='*', s = 100 * 2, label = 'Female')
plt.xlabel('weight', fontsize=16)
plt.ylabel('height', fontsize=16)
plt.title('scatter plot - height vs weight',fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ## 4. Bar Chart
#
# A bar graph is a pictorial rendition of statistical data in which the independent variable can attain only certain discrete values. The dependent variable may be discrete or continuous. The most common form of bar graph is the vertical bar graph, also called a column graph.
#
# #### The following are advantages of bar graph:
# - Show each data category in a frequency distribution
# - isplay relative numbers/proportions of multiple categories
# - Summarize a large amount of data in a visual, easily intepretable form
# - Make trends easier to highlight than tables do
# - Estimates can be made quickly and accurately
# - Permit visual guidance on accuracy and reasonableness of calculations
# - Accessible to a wide audience

# %%
City=['Delhi','Beijing','Washington','Tokyo','Moscow']
Price_sqft_in_K=[60,40,70,65,45]
 
plt.bar(City,Price_sqft_in_K,color='skyblue',edgecolor='green')

plt.xlabel('City', fontsize=16)
plt.ylabel('Price_sft_in_K', fontsize=16)
plt.title('Barchart - Price_sft_in_K across cities',fontsize=20)
plt.show()

# %% [markdown]
# ## Horizontal Bar Chart

# %%
City=['Delhi','Beijing','Washington','Tokyo','Moscow']

Price_sqft_in_K=[60,40,70,65,45]
 
plt.barh(City,Price_sqft_in_K,color='skyblue',edgecolor='yellow')

plt.xlabel('Price per SQ FT', fontsize=16)
plt.ylabel('City', fontsize=16)
plt.title('Barchart - Price_sft_in_K across cities',fontsize=20)
plt.show()

# %% [markdown]
# ## Stacked Bar Chart
#
# A stacked bar chart, also known as a stacked bar graph, is a graph that is used to break down and compare parts of a whole. Each bar in the chart represents a whole, and segments in the bar represent different parts or categories of that whole. Different colors are used to illustrate the different categories in the bar.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
City=['Delhi','Beijing','Washington','Tokyo','Moscow']

Price_sqft_in_K_center = [60,40,70,65,45]
Price_sqft_in_K_outer = [45,22,50,52,20]

location = ['center', 'outer']
 
plt.barh(City,Price_sqft_in_K_center,color='skyblue',edgecolor='yellow')
plt.barh(City,Price_sqft_in_K_outer,color='darkblue',edgecolor='yellow')

plt.xlabel('Price_sft_in_K', fontsize=16)
plt.ylabel('City', fontsize=16)
plt.title('Barchart - Price_sft_in_K across cities',fontsize=20)
plt.legend(location, loc = 0)
plt.show()

# %%
City=['Delhi','Beijing','Washington','Tokyo','Moscow']

Price_sqft_in_K_center = [60,40,70,65,45]
Price_sqft_in_K_outer = [45,22,50,52,20]

location = ['center', 'outer']
 
plt.bar(City,Price_sqft_in_K_center,color='skyblue',edgecolor='yellow')
plt.bar(City,Price_sqft_in_K_outer,color='darkblue',edgecolor='yellow')

plt.xlabel('City', fontsize=16)
plt.ylabel('Price_sft_in_K', fontsize=16)
plt.title('Barchart - Price_sft_in_K across cities',fontsize=20)
plt.legend(location, loc = 0)
plt.show()

# %% [markdown]
# ### Grouped Bar Chart
#
# Grouped bar charts require three columns or rows of data from your DataSet—one for series, one for categories, and one for values. If you have more than two series, each additional series is implemented as an additional bar. For information about value, category, and series data, see Understanding Chart Data.
#
# The following graphic shows you how the data from the series, categories, and values columns in a typical column-based spreadsheet is converted into a vertical grouped bar chart:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
city=['Delhi','Beijing','Washington','Tokyo','Moscow']

Price_sqft_in_K_center = [60,40,70,65,15]
Price_sqft_in_K_outer = [45,22,50,52,20]


pos = np.arange(len(city))
print(pos)
w = 0.3
# plt.figure(figsize=(10,10))
plt.bar(pos,Price_sqft_in_K_center,width = w,color='skyblue',edgecolor='yellow', label = 'City Center')
plt.bar(pos+w,Price_sqft_in_K_outer,width = w,color='darkblue',edgecolor='yellow', label = 'Outskirts')

plt.xticks(pos, city)

plt.xlabel('City', fontsize=16)
plt.ylabel('Price_sft_in_K', fontsize=16)
plt.title('Barchart - Price_sft_in_K across cities',fontsize=20)
plt.legend(loc = 0)
plt.show()
# Out:
# [0 1 2 3 4]

# %% [markdown]
# ## 5. Box plot
#
#
# Description
# A Box and Whisker Plot (or Box Plot) is a convenient way of visually displaying the data distribution through their quartiles.
#
# The lines extending parallel from the boxes are known as the “whiskers”, which are used to indicate variability outside the upper and lower quartiles. Outliers are sometimes plotted as individual dots that are in-line with whiskers. Box Plots can be drawn either vertically or horizontally.
#
# Although Box Plots may seem primitive in comparison to a Histogram or Density Plot, they have the advantage of taking up less space, which is useful when comparing distributions between many groups or datasets.
#
# For some distributions/datasets, you will find that you need more information than the measures of central tendency (median, mean, and mode)
#
# - Boxplots are a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile (Q1), median, third quartile (Q3), and “maximum”).
# - median (Q2/50th Percentile): the middle value of the dataset.
# - first quartile (Q1/25th Percentile): the middle number between the smallest number (not the “minimum”) and the median of the dataset.
# - third quartile (Q3/75th Percentile): the middle value between the median and the highest value (not the “maximum”) of the dataset.
# - interquartile range (IQR): 25th to the 75th percentile.
# - whiskers (shown in blue)
# - outliers (shown as green circles)
#     “maximum”: Q3 + 1.5*IQR
#     “minimum”: Q1 -1.5*IQR
# What defines an outlier, “mini

# %% [markdown]
# Box-and-Whisker Plots
# To understand box-and-whisker plots, you have to understand medians and quartiles of a data set.
#
# The median is the middle number of a set of data, or the average of the two middle numbers (if there are an even number of data points).
#
# The median ( Q2 ) divides the data set into two parts, the upper set and the lower set. The lower quartile ( Q1 ) is the median of the lower half, and the upper quartile ( Q3 ) is the median of the upper half.
#
# Example:
#
# Find Q1 , Q2 , and Q3 for the following data set, and draw a box-and-whisker plot.
#
# {2,6,7,8,8,11,12,13,14,15,22,23}
#
# There are 12 data points. The middle two are 11 and 12 . So the median, Q2 , is 11.5 .
#
# The "lower half" of the data set is the set {2,6,7,8,8,11} . The median here is 7.5 . So Q1=7.5 .
#
# The "upper half" of the data set is the set {12,13,14,15,22,23} . The median here is 14.5 . So Q3=14.5 .
#
# A box-and-whisker plot displays the values Q1 , Q2 , and Q3 , along with the extreme values of the data set ( 2 and 23 , in this case):
#
# ![image.png](attachment:image.png)
#
#
#
# A box & whisker plot shows a "box" with left edge at Q1 , right edge at Q3 , the "middle" of the box at Q2 (the median) and the maximum and minimum as "whiskers".
#
# Note that the plot divides the data into 4 equal parts. The left whisker represents the bottom 25% of the data, the left half of the box represents the second 25% , the right half of the box represents the third 25% , and the right whisker represents the top 25% .
#
# Outliers
# If a data value is very far away from the quartiles (either much less than Q1 or much greater than Q3 ), it is sometimes designated an outlier . Instead of being shown using the whiskers of the box-and-whisker plot, outliers are usually shown as separately plotted points.
#
# The standard definition for an outlier is a number which is less than Q1 or greater than Q3 by more than 1.5 times the interquartile range ( IQR=Q3−Q1 ). That is, an outlier is any number less than Q1−(1.5×IQR) or greater than Q3+(1.5×IQR) .
#
# Example:
#
# Find Q1 , Q2 , and Q3 for the following data set. Identify any outliers, and draw a box-and-whisker plot.
#
# {5,40,42,46,48,49,50,50,52,53,55,56,58,75,102}
#
# There are 15 values, arranged in increasing order. So, Q2 is the 8th data point, 50 .
#
# Q1 is the 4th data point, 46 , and Q3 is the 12th data point, 56 .
#
# The interquartile range IQR is Q3−Q1 or 56−47=10 .
#
# Now we need to find whether there are values less than Q1−(1.5×IQR) or greater than Q3+(1.5×IQR) .
#
# Q1−(1.5×IQR)=46−15=31
#
# Q3+(1.5×IQR)=56+15=71
#
# Since 5 is less than 31 and 75 and 102 are greater than 71 , there are 3 outliers.
#
# The box-and-whisker plot is as shown. Note that 40 and 58 are shown as the ends of the whiskers, with the outliers plotted separately.
#
# ![image.png](attachment:image.png)

# %%
# Data: Salaries in lacs
fresher = np.round(np.random.uniform(3.5, 6.5, size = 10),1)
lead = np.round(np.random.uniform(5.5, 12.5, size = 10),1)
manager = np.round(np.random.uniform(8.5, 16.5, size = 10),1)
director = np.round(np.random.uniform(18.25, 34, size = 10),1)
vp = np.round(np.random.uniform(27, 50.5, size = 10),1)
cxo = np.round(np.random.uniform(45.5,75, size = 10),1)

# %%
plt.figure(figsize=(15,10))
box_plot_data=[fresher,lead,manager,director,vp,cxo]
plt.boxplot(box_plot_data)
plt.show()

# %% [markdown]
# ## Add few more properties¶

# %%
plt.figure(figsize=(15,10))
box_plot_data=[fresher,lead,manager,director,vp,cxo]
plt.boxplot(box_plot_data,patch_artist=True,
            labels=['fresher','lead','manager','director','vp','cxo'])
plt.show()

# %% [markdown]
# ## Horizontal Box Plot¶

# %%
plt.figure(figsize=(15,10))
box_plot_data=[fresher,lead,manager,director,vp,cxo]
plt.boxplot(box_plot_data,patch_artist=True, 
            labels=['fresher','lead','manager','director','vp','cxo'], 
            vert=0)
plt.show()

# %% [markdown]
# zip() in Python
# Difficulty Level : Basic
# Last Updated : 30 Sep, 2021
# Python zip() method takes iterable or containers and returns a single iterator object, having mapped values from all the containers.
#
# It is used to map the similar index of multiple containers so that they can be used just using a single entity.
#
# Syntax :  zip(*iterators)
#
# Parameters : Python iterables or containers ( list, string etc )
# Return Value : Returns a single iterator object, having mapped values from all the
# containers.
#
# Python zip() example
# Example 1: Python zip two lists
# Python3
# name = [ "Manjeet", "Nikhil", "Shambhavi", "Astha" ]
# roll_no = [ 4, 1, 3, 2 ]
#
# # using zip() to map values
# mapped = zip(name, roll_no)
#
# print(set(mapped))
# Output:
#
# {('Shambhavi', 3), ('Nikhil', 1), ('Astha', 2), ('Manjeet', 4)}
# Example 2: Python zip enumerate
# Python3
# names = ['Mukesh', 'Roni', 'Chari']
# ages = [24, 50, 18]
#
# for i, (name, age) in enumerate(zip(names, ages)):
#     print(i, name, age)
# Output:
#
# 0 Mukesh 24
# 1 Roni 50
# 2 Chari 18

# %%
plt.figure(figsize=(15,10))
box_plot_data=[fresher,lead,manager,director,vp,cxo]

box = plt.boxplot(box_plot_data,patch_artist=True, 
                  labels=['fresher','lead','manager','director','vp','cxo'], 
                  vert=0)

colors = ['darkblue', 'aqua', 'lime', 'black', 'indigo', 'teal']
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)
    
plt.show()

# %%
box['boxes']

# %% [markdown]
# ## 6. Histogram

# %% [markdown]
# Histograms are graphical representations of a probability distribution. A histogram is a
# kind of a bar chart.
#
# Using matplotlib and its bar chart function, you can create histogram charts.
#
# #### Advantages of Histogram charts:
#     • They display the number of values within a specified interval.
#     • They are suitable for large datasets as they can be grouped within the intervals.

# %%
values = np.random.randint(24,100, size = 65)
plt.hist(values,bins= 5, histtype='step', align='mid', 
         color='g', label='Test Score Data')
plt.legend(loc= 0)
plt.title('Histogram of score')
plt.show()

# %%
values = np.random.randint(24,100, size = 65)

plt.figure(figsize=(15,5))
plt.hist(values,bins=7, histtype='bar',align='mid', color='c', 
         label='Test score Data',edgecolor='black')
plt.legend()
plt.title('Histogram of score')
plt.show()

# %% [markdown]
# ### We can play with the bins by changing the values
# ### we can also pass bins = "auto" which will automatically take

# %% [markdown]
# ## Seaborn

# %%
import seaborn as sns
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

#themes: darkgrid, whitegrid, dark, white, and ticks
 
sns.set_style("whitegrid")

# %% [markdown]
# Plot Styles
# Colors, font sizes, line thickness, and many other plot attributes all have default values in Matplotlib. In addition to the default style for these plot attributes, additional styles are available. To use the default style, either don't specify a style or use the line plt.style.use('default'). If you want to apply a different style to a plot use the line:
#
#
# plt.style.use('style')
# The 'style' is supplied to the method as a string, surrounded by quotes.
#
# The code below builds a plot with 'fivethirtyeight' style, a style similar to the plots on fivethirtyeight.com.
#
# ![download.png](attachment:download.png)

# %%
plt.style.use('seaborn-bright') #fivethirtyeight, default, classic, bmh, grayscale

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
tips_df = sns.load_dataset('tips')

# %% [markdown]
# The tips data set is a simple dataset that consists of observations on tip providers in restaurants. The data consists of the following features :
#
# total_bill: The total bill paid by the customer.
# - tip: The tip provided by the customer.
# - sex: The gender of the customer.
# - smoker: If the customer is a smoker or not.
# - day: The day of the week when the observation was made.
# - time: The time of the observation, whether at lunch or dinner etc.
# - size: The size of the group whether there were multiple members

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips_df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# ## 1. Scatter Plot
# Scatter plots are used when you want to show the relationship between two variables. Scatter plots are sometimes called correlation plots because they show how two variables are correlated.

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips_df);

# %% [markdown]
# Observation:From the above scatter plot, we can see that as the total_bill increases the tip is also expected to increase.

# %% [markdown]
# ## 2. Line Plot
# Line chart is used when you want to emphasize changes in values for one variable (plotted on the vertical axis) for continuous values of a second variable (plotted on the horizontal).
#
# On the horizontal axis, you need a variable that depicts continuous values that have a regular interval of measurement - like minute, hour, day, week, or month etc.,
#
# On the vertical axis, you will report the value of a second numeric variable for points that fall in each of the intervals defined by the horizontal-axis variable.

# %%
sns.lineplot(x="size", y="tip",data=tips_df);

# %%
import seaborn as sns
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

#themes: darkgrid, whitegrid, dark, white, and ticks
 
sns.set_style("whitegrid")

# %%
tips_df = sns.load_dataset('tips')

# %% [markdown]
# ## 3. Dist Plot
# The dist plot or distribution plot plots the occurrences or density of the specified feature in the dataset.

# %%
plt.figure(figsize=(15,5))
plt.hist(tips_df['tip'], bins = 9, color='grey')
plt.xticks(np.arange(0,11,1))
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.distplot(tips_df['tip'], bins=9)
plt.xticks(np.arange(0,11,1))
plt.show()

# %% [markdown]
# Observation: We can see that most of the tips given by the customers lie between the range of 2 and 4.

# %%
# find all the records where tip is between 2 - 2.5
# tip between 3 - 3.5

print(tips_df[(tips_df.tip >= 7) & (tips_df.tip <= 10)].shape[0])

print(tips_df.shape[0])

print(tips_df[(tips_df.tip >= 7) & (tips_df.tip <= 10)].shape[0]/tips_df.shape[0])
# Out:
# 3
# 244
# 0.012295081967213115

# %% [markdown]
# # 4. Bar Plot

# %% [markdown]
# A bar chart depicts numeric values against distinct categories in a two-axis plot. On one axis, the category levels are listed. For each category, one bar is plotted, and its length along the other axis corresponds with the numeric value associated with the category.

# %%
plt.figure(dpi = 50)
sns.barplot(x="day", y="tip", data = tips_df)

# %% [markdown]
# Both the bar chart and pie chart are common choices when it comes to plotting numeric values against categorical labels. Generally, the bar chart is versatile and pie pie chart is a right choice when individual groups values must sum up to a meaningful total and a part-to-whole comparison is required.

# %% [markdown]
# 5. Kernel Density Plot

# %% [markdown]
# Like histograms, KDE or kernel density or simply, density plot visualizes the distribution of data over a continuous interval or time period.The peaks of a Density Plot displays where exactly the values are concentrated over the interval.

# %%
plt.figure(dpi=1200)
sns.kdeplot(tips_df['tip']);

# %% [markdown]
# # 6. Reg Plot

# %% [markdown]
# Regression plot plots the data points and also draws a regression line.

# %%
plt.figure(dpi = 300)
sns.regplot(x="total_bill", y="tip", data=tips_df);

# %% [markdown]
# ### 7. Box Plot
#
# Box plots are very useful plots that can covey the distribution of values, the maximum and median values. Also mainly helpful in visualizing the outliers in the data.

# %%
plt.figure(dpi = 100)
sns.boxplot(x="size", y="tip", data = tips_df);

# %%
tips_df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %% [markdown]
# Adding `hue="smoker" represent that you want to use “smoker”
# for color encoding i.e. color the data points for smoker and non-smoker differently.

# %%
plt.figure(figsize=(15,5))
plt.figure(dpi = 100)
# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="sex", y="tip",
            hue="smoker", #palette=["coral", "yellow"],
            data=tips_df);

# %% [markdown]
# # 8. Cat Plot
#
#
# The categorical plot shows the **relationship between a numerical and one or more categorical variables** in the data.
#
# plt.figure(dpi = 300)

# %% [markdown]
# Categorical distribution plots:
#
# - :func:`boxplot` (with ``kind="box"``)
# - :func:`violinplot` (with ``kind="violin"``)
# - :func:`boxenplot` (with ``kind="boxen"``)
#
# Categorical estimate plots:
#
# - :func:`pointplot` (with ``kind="point"``)
# - :func:`barplot` (with ``kind="bar"``)
# - :func:`countplot` (with ``kind="count"``)

# %% [markdown]
# ### About Violin plot
#
# - A violin plot is a hybrid of a box plot and a kernel density plot, which shows peaks in the data.
#
# - The box plot is an old standby for visualizing basic distributions. It's convenient for comparing summary statistics (such as range and quartiles), but it doesn't let you see variations in the data. For multimodal `distributions (those with multiple peaks) this can be particularly limiting.`

# %%
plt.figure(dpi = 300)
sns.catplot(x="day", y="tip", data = tips_df, kind='violin');

# %% [markdown]
# **kind = "swarm":** A swarm plot can be drawn on its own, but it is also a good complement to a box or violin plot in cases where you want to show all observations along with some representation of the underlying distribution.

# %%
sns.catplot(x="total_bill", y="day", hue="sex",
            kind="swarm",
            data=tips_df);

# %% [markdown]
# ### 9. Joint Plot
# The joint plot allows us to draw a plot of two variables with bivariate and univariate graphs. Kind = ‘scatter’, ‘reg’, ‘resid’, ‘kde’, or ‘hex’.

# %%
plt.figure(dpi = 300)
sns.jointplot(x='total_bill',y='tip',data=tips_df,kind='reg');

# %% [markdown]
# #### The above plot shows a regression plot between tip and total_bill and also compares the density distribution of the two variables.

# %% [markdown]
# ### 10. Count Plot
# Count plot lets us easily plot a feature against the number of observations or occurances. It like plotting the frequency of the values in a column.

# %%
plt.figure(dpi = 75)
sns.countplot(x='smoker',data=tips_df);

# %% [markdown]
# tight_layout automatically adjusts subplot params so that the subplot(s) fits in to the figure area.
# This is an experimental feature and may not work for some cases. It only checks the extents of ticklabels,
# axis labels, and titles.
#
# Below code is for overapping of names in x axis
# ax.set_xticklabels(k.get_xticklabels(), rotation=40, ha="right")
# ax.set_xticklabels(ax.get_xticklabels(), fontsize=7)

# %%
plt.figure(dpi = 75)
sns.countplot(x='day',hue = 'smoker',data=tips_df);

# %% [markdown]
# ### 11. Pair Plot
# One of the simplest ways to visualize the relation between all features, the pair plot method plots all the pair relationships in the dataset at once.

# %%
plt.figure(dpi = 1200)
#sns.pairplot(tips_df);
sns.pairplot(tips_df, hue = 'day');

# %% [markdown]
# ### 12. Relational Plot
# The relplot function provides access to several different axes-level functions that show the relationship between any two variables.

# %%
plt.figure(dpi = 1200)
sns.relplot(x="total_bill", y="tip", hue="smoker",col="day", style="sex",
           data=tips_df);

# %% [markdown]
# - col: The feature to be visualized in subplots column.
# - hue: The feature to be represented or distinguished with different colours.
# - style: The feature to be represented or distinguished with different styles.

# %% [markdown]
# ### 13. Heat Map
# Heat maps are very useful and intuitive plots when we have a matrix of data. Especially used to plot the correlation matrix.

# %%
tips_df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
plt.figure(dpi = 300)
sns.heatmap(tips_df.corr(),linecolor='white',linewidths=2,annot=True);

# %%
# matplotlib version

import matplotlib
matplotlib.__version__
# Out:
# '3.3.2'

# %% [markdown]
# ## Figures and Subplots
#
# You often need to create multiple plots in the same figure, as we'll see in some upcoming examples.
#
#
# ```matplotlib``` has the concept of **figures and subplots** using which you can create *multiple subplots inside the same figure*.
#
# To create multiple plots in the same figure, you can use the method ```plt.subplot(nrows, ncols, nsubplot)```.

# %% [markdown]
# - A figure with subplots
#
# - An array of 2 dimensional Subplot

# %% [markdown]
# ## 4 subplots
#             1 Figure                  Column 1  Column 2
#                              1 - Row      2       2
#                              2 - Row      2       2

# %%
# Example: Create a figure having 4 subplots
x = np.linspace(1, 10, 100)

# Optional command, since matplotlib creates a figure by default anyway
plt.figure(1)

# subplot 1
plt.subplot(1, 2, 1)  # row 1, columns 2 , position 1 
plt.title("Linear")
plt.plot(x, x)


# subplot 2 
plt.subplot(1, 2, 2) # row 1, columns 2 , position 2
plt.title("Cubic")
plt.plot(x, x**3)



# subplot 3
plt.figure(2)
plt.subplot(2, 2, 1) # row 2, columns 2 , position 1
plt.title("Log")
plt.plot(x, np.log(x))

# subplot 4 
plt.subplot(2, 2, 2)  # row 2, columns 2 , position 2
plt.title("Exponential")
plt.plot(x, x**2)


plt.show()

# %%
plt.figure(dpi = 60)
plt.plot([1, 2, 3])
plt.plot([4, 5, 6])

# %%
plt.figure(dpi = 60)

plt.subplot(1,2,1)
sns.barplot(x="day", y="tip", data = tips_df)

plt.subplot(122)
sns.barplot(x="smoker", y="tip", data = tips_df)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='tip'>

# %%
plt.figure(dpi = 60)

plt.subplot(211)
sns.barplot(x="day", y="tip", data = tips_df)

plt.subplot(212)
sns.barplot(x="smoker", y="tip", data = tips_df);

# %%
plt.figure(dpi = 100)


plt.figure(1)                # the first figure
plt.subplot(211)             # the first subplot in the first figure
sns.barplot(x="day", y="tip", data = tips_df)

plt.subplot(212)             # the second subplot in the first figure
sns.barplot(x="smoker", y="tip", data = tips_df)


plt.figure(2)                # a second figure
sns.barplot(x="sex", y="tip", data = tips_df)          # creates a subplot(111) by default

plt.figure(3)               
plt.subplot(121)             
sns.heatmap(tips_df.corr(),linecolor='white',linewidths=2,annot=True)        
plt.subplot(122)             
sns.countplot(x='smoker',data=tips_df)        

plt.figure(1)                
plt.subplot(211)             
plt.title('Day vs Tip') 
plt.subplot(212)             
plt.title('Smoker vs Tip') 

plt.tight_layout() # tight_layout() will also adjust spacing between subplots to minimize the overlaps.

plt.show()
# Out:
# <ipython-input-42-c04a840e7398>:22: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(211)
# <ipython-input-42-c04a840e7398>:24: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(212)

# %%
plt.figure(dpi = 300)
plt.figure(figsize=(15,10))

plt.subplot(221)
sns.countplot(x='smoker',data=tips_df)

plt.subplot(223)
sns.boxplot(x="size", y="tip", data = tips_df)

plt.subplot(122)
sns.heatmap(tips_df.corr(),linecolor='white',linewidths=2,annot=True)

plt.tight_layout(pad= 1.0, w_pad=15.5, h_pad=15.5)

plt.show()

# %%
plt.figure(dpi = 300)
plt.figure(figsize=(15,10))

plt.subplot(221)
sns.countplot(x='smoker',data=tips_df)

plt.subplot(222)
sns.boxplot(x="size", y="tip", data = tips_df)

plt.subplot(223)
sns.heatmap(tips_df.corr(),linecolor='white',linewidths=2,annot=True)

plt.subplot(224)
sns.scatterplot(x="total_bill", y="tip", data=tips_df)

plt.tight_layout(pad= 1.0, w_pad=1.5, h_pad=1.5)

plt.show()

# %% [markdown]
# ## Lets See Subplot based using Columns wrap in Relplot

# %% [markdown]
# ## Columns Wrap

# %%
plt.figure(dpi = 1200)
sns.relplot(x="total_bill", y="tip",col="day",col_wrap=2, style="sex",
           data=tips_df)

# %% [markdown]
# ### Using Cross tab:
#
# Compute a simple cross-tabulation of two (or more) factors. By default computes a frequency table of the factors unless an array of values and an aggregation function are passed
#
#                                        index,
#                             columns,
#                             values=None,
#                             rownames=None,
#                             colnames=None,
#                             aggfunc=None,
#                             margins=False,
#                             margins_name='All',
#                             dropna=True,
#                             normalize=False,

# %%
import pandas as pd 
pd.crosstab(tips_df["day"],tips_df["sex"])
# Out:
# sex   Male  Female
# day
# Thur    30      32
# Fri     10       9
# Sat     59      28
# Sun     58      18

# %%
pd.crosstab(tips_df["day"],tips_df["sex"]).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='day'>

# %%
pd.crosstab(tips_df["day"],tips_df["sex"], margins=True)
# Out:
# sex   Male  Female  All
# day
# Thur    30      32   62
# Fri     10       9   19
# Sat     59      28   87
# Sun     58      18   76
# All    157      87  244

# %%
plt.figure(dpi = 75)
pd.crosstab(tips_df["day"],tips_df["sex"], margins=True).plot(kind="bar", yticks=np.arange(0,260,25), 
                                                              title ="Incluidng Total Aggregation" )
# Out:
# <AxesSubplot:title={'center':'Incluidng Total Aggregation'}, xlabel='day'>

# %% [markdown]
# ## Grouped Bar Graph with Count on Y axis Using Seaborn Catplot

# %%
sns.catplot(x="day",  hue="sex", data = tips_df, kind='count',height=5, aspect=.8);

# %%
sns.catplot(x="day",  col="sex", data = tips_df, kind='count',height=5, aspect=.8);
